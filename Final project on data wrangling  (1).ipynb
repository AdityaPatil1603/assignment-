# %% [markdown]
# # 1. Import the dataset using Pandas from above mentioned url

# %%
# Importing the data from website 
import pandas as pd 
import numpy as np 
import datetime 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
url='https://raw.githubusercontent.com/SR1608/Datasets/main/covid-data.csv'

# %%
df=pd.read_csv(url)
df.head()
# Out:
#   iso_code continent     location      date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  31/12/19          NaN        0.0
# 1      AFG      Asia  Afghanistan  01/01/20          NaN        0.0
# 2      AFG      Asia  Afghanistan  02/01/20          NaN        0.0
# 3      AFG      Asia  Afghanistan  03/01/20          NaN        0.0
# 4      AFG      Asia  Afghanistan  04/01/20          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %% [markdown]
# # 2. High Level Data Understanding:

# %%
# a.Finding no. of rows and columns in dataframe 
print('no of rows in dataset :',len(df.axes[0]))
print('no of columns in dataset:',len(df.axes[1]))
# Out:
# no of rows in dataset : 57394
# no of columns in dataset: 49

# %%
# b. Data types of columns.
df.dtypes
# Out:
# iso_code                               object
# continent                              object
# location                               object
# date                                   object
# total_cases                           float64
# new_cases                             float64
# new_cases_smoothed                    float64
# total_deaths                          float64
# new_deaths                            float64
# new_deaths_smoothed                   float64
# total_cases_per_million               float64
# new_cases_per_million                 float64
# new_cases_smoothed_per_million        float64
# total_deaths_per_million              float64
# new_deaths_per_million                float64
# new_deaths_smoothed_per_million       float64
# reproduction_rate                     float64
# icu_patients                          float64
# icu_patients_per_million              float64
# hosp_patients                         float64
# ...

# %%
#c.Info of data in dataframe.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57394 entries, 0 to 57393
# Data columns (total 49 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso_code                            57071 non-null  object
#  1   continent                           56748 non-null  object
#  2   location                            57394 non-null  object
#  3   date                                57394 non-null  object
#  4   total_cases                         53758 non-null  float64
#  5   new_cases                           56465 non-null  float64
#  6   new_cases_smoothed                  55652 non-null  float64
#  7   total_deaths                        44368 non-null  float64
#  8   new_deaths                          56465 non-null  float64
#  9   new_deaths_smoothed                 55652 non-null  float64
#  10  total_cases_per_million             53471 non-null  float64
# ...

# %%
# c.describe of data in dataframe.
df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  5.375800e+04   56465.000000        55652.000000  4.436800e+04
# mean   1.677974e+05    1953.576941         1920.431953  6.858639e+03
# std    1.693038e+06   18269.650340        17777.391785  5.578081e+04
# min    1.000000e+00   -8261.000000         -552.000000  1.000000e+00
# 25%    1.800000e+02       0.000000            0.857000  1.300000e+01
# 50%    2.070000e+03      14.000000           19.429000  8.400000e+01
# 75%    2.235675e+04     235.000000          245.286000  7.270000e+02
# max    5.515465e+07  646281.000000       584981.857000  1.328537e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  56465.000000         55652.000000             53471.000000
# mean      47.054317            46.835439              3139.099982
# std      390.853776           378.272794              6183.455260
# min    -1918.000000          -232.143000                 0.001000
# ...

# %% [markdown]
# # 3. Low Level Data Understanding :

# %%
#a. Find count of unique values in location column
df['location'].nunique()
# Out:
# 216

# %%
# b.Find which continent has maximum frequency using values counts.
df['continent'].value_counts().head(1)
# Out:
# Europe    14828
# Name: continent, dtype: int64

# %%
# c. Find maximum & mean value in 'total_cases'.
print('maximum value of total casese:',df['total_cases'].max())
print('mean value of total cases:',df['total_cases'].mean())
# Out:
# maximum value of total casese: 55154651.0
# mean value of total cases: 167797.3688753302

# %%
# d.Find 25%,50% & 75% quartile value in 'total_deaths'.
print('25% quartile value in total_deaths:',df['total_deaths'].quantile(q=0.25))
print('50% quartile value in total_deaths:',df['total_deaths'].quantile(q=0.50))
print('75% quartile value in total_deaths:',df['total_deaths'].quantile(q=0.75))
# Out:
# 25% quartile value in total_deaths: 13.0
# 50% quartile value in total_deaths: 84.0
# 75% quartile value in total_deaths: 727.0

# %%
# e.Find which continent has maximum'human_development_index'.
df.groupby('continent')['human_development_index'].max().sort_values(ascending=False).head(1)
# Out:
# continent
# Europe    0.953
# Name: human_development_index, dtype: float64

# %%
# f.Find which continent has minimum 'gdp_per_capita'.
df.groupby('continent')['gdp_per_capita'].min().sort_values(ascending=True).head(1)
# Out:
# continent
# Africa    661.24
# Name: gdp_per_capita, dtype: float64

# %% [markdown]
# # 4.Filter the dataframe with only this columns['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index'] and update the data frame.

# %%
#. Filter the dataframe with only this columns['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index'] and update the data frame.
df.loc[:, df.columns.isin(['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index'] )]
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          NaN           NaN
# 1          Asia    Afghanistan  01/01/20          NaN           NaN
# 2          Asia    Afghanistan  02/01/20          NaN           NaN
# 3          Asia    Afghanistan  03/01/20          NaN           NaN
# 4          Asia    Afghanistan  04/01/20          NaN           NaN
# ...         ...            ...       ...          ...           ...
# 57389       NaN  International  13/11/20        696.0           7.0
# 57390       NaN  International  14/11/20        696.0           7.0
# 57391       NaN  International  15/11/20        696.0           7.0
# 57392       NaN  International  16/11/20        696.0           7.0
# 57393       NaN  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %% [markdown]
# # 5. Data Cleaning

# %%
# a.Remove all duplicates observations
df.drop_duplicates(inplace=True)

# %%
# b.Find missing values in all columns
df.isna()
# Out:
#        iso_code  continent  location   date  total_cases  new_cases  \
# 0         False      False     False  False         True      False
# 1         False      False     False  False         True      False
# 2         False      False     False  False         True      False
# 3         False      False     False  False         True      False
# 4         False      False     False  False         True      False
# ...         ...        ...       ...    ...          ...        ...
# 57389      True       True     False  False        False       True
# 57390      True       True     False  False        False       True
# 57391      True       True     False  False        False       True
# 57392      True       True     False  False        False       True
# 57393      True       True     False  False        False       True
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
# c.Remove all observations where continent column value is missing
df.dropna(subset=['continent'])
# Out:
#       iso_code continent     location      date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  31/12/19          NaN        0.0
# 1          AFG      Asia  Afghanistan  01/01/20          NaN        0.0
# 2          AFG      Asia  Afghanistan  02/01/20          NaN        0.0
# 3          AFG      Asia  Afghanistan  03/01/20          NaN        0.0
# 4          AFG      Asia  Afghanistan  04/01/20          NaN        0.0
# ...        ...       ...          ...       ...          ...        ...
# 56743      ZWE    Africa     Zimbabwe  13/11/20       8696.0       29.0
# 56744      ZWE    Africa     Zimbabwe  14/11/20       8765.0       69.0
# 56745      ZWE    Africa     Zimbabwe  15/11/20       8786.0       21.0
# 56746      ZWE    Africa     Zimbabwe  16/11/20       8786.0        0.0
# 56747      ZWE    Africa     Zimbabwe  17/11/20       8897.0      111.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
# d.Fill all missing values with 0.
df.fillna(0, inplace=True)

# %% [markdown]
# # 6. Date time format :

# %%
# a. Convert date column in datetime format using pandas.to_datetime
df['date']=pd.to_datetime(df['date'])

# %%
df.head()
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan 2019-12-31          NaN        0.0
# 1      AFG      Asia  Afghanistan 2020-01-01          NaN        0.0
# 2      AFG      Asia  Afghanistan 2020-02-01          NaN        0.0
# 3      AFG      Asia  Afghanistan 2020-03-01          NaN        0.0
# 4      AFG      Asia  Afghanistan 2020-04-01          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
# b. Create new column month after extracting month data from date column.
df['month'] = pd.DatetimeIndex(df['date']).month
df.head()
# Out:
#   iso_code continent     location      date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  31/12/19          NaN        0.0
# 1      AFG      Asia  Afghanistan  01/01/20          NaN        0.0
# 2      AFG      Asia  Afghanistan  02/01/20          NaN        0.0
# 3      AFG      Asia  Afghanistan  03/01/20          NaN        0.0
# 4      AFG      Asia  Afghanistan  04/01/20          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# ...

# %% [markdown]
# # 7. Data Aggregation:

# %%
#a. Find max value in all columns using groupby function on 'continent' column
df.groupby('continent').max().reset_index()
# Out:
#        continent iso_code                      location      date  \
# 0         Africa      ZWE                      Zimbabwe  31/12/19
# 1           Asia      YEM                         Yemen  31/12/19
# 2         Europe      VAT                       Vatican  31/12/19
# 3  North America      VIR  United States Virgin Islands  31/12/19
# 4        Oceania      WLF             Wallis and Futuna  31/12/19
# 5  South America      VEN                     Venezuela  31/12/19
#
#    total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0     752269.0    13944.0           12583.714       20314.0       572.0
# 1    8874290.0    97894.0           93198.571      130519.0      2003.0
# 2    1991233.0    86852.0           54868.571       52147.0      2004.0
# 3   11205486.0   184813.0          156419.143      247220.0      4928.0
# 4      27750.0     1384.0             551.714         907.0        59.0
# ...

# %%
# b. Store the result in a new dataframe named 'df_groupby'.
df_groupby = df.groupby('continent').max().reset_index()
df_groupby.head(10)
# Out:
#        continent iso_code                      location      date  \
# 0         Africa      ZWE                      Zimbabwe  31/12/19
# 1           Asia      YEM                         Yemen  31/12/19
# 2         Europe      VAT                       Vatican  31/12/19
# 3  North America      VIR  United States Virgin Islands  31/12/19
# 4        Oceania      WLF             Wallis and Futuna  31/12/19
# 5  South America      VEN                     Venezuela  31/12/19
#
#    total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0     752269.0    13944.0           12583.714       20314.0       572.0
# 1    8874290.0    97894.0           93198.571      130519.0      2003.0
# 2    1991233.0    86852.0           54868.571       52147.0      2004.0
# 3   11205486.0   184813.0          156419.143      247220.0      4928.0
# 4      27750.0     1384.0             551.714         907.0        59.0
# ...

# %% [markdown]
# # 8. Feature Engineering :

# %%
# a. Create a new feature 'total_deaths_to_total_cases' by ratio of
df_groupby['total_deaths_to_total_cases'] = df_groupby['total_deaths'] / df_groupby['total_cases']
df_groupby.to_csv(url, index=False)
df_groupby.head(30)
# Out:
#        continent iso_code                      location      date  \
# 0         Africa      ZWE                      Zimbabwe  31/12/19
# 1           Asia      YEM                         Yemen  31/12/19
# 2         Europe      VAT                       Vatican  31/12/19
# 3  North America      VIR  United States Virgin Islands  31/12/19
# 4        Oceania      WLF             Wallis and Futuna  31/12/19
# 5  South America      VEN                     Venezuela  31/12/19
#
#    total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0     752269.0    13944.0           12583.714       20314.0       572.0
# 1    8874290.0    97894.0           93198.571      130519.0      2003.0
# 2    1991233.0    86852.0           54868.571       52147.0      2004.0
# 3   11205486.0   184813.0          156419.143      247220.0      4928.0
# 4      27750.0     1384.0             551.714         907.0        59.0
# ...

# %%
# a. Perform Univariate analysis on 'gdp_per_capita' column by plotting\histogram using seaborn dist plot.
sns.distplot(df_groupby['gdp_per_capita'], kde=False, bins=10)
plt.xlabel('GDP per capita')
plt.ylabel('Frequency')
plt.title('Distribution of GDP per capita')
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Distribution of GDP per capita')

# %%
# b.Plot a scatter plot of 'total_cases' & 'gdp_per_capita'
sns.scatterplot(x='gdp_per_capita', y='total_cases', data=df_groupby, color='blue')
plt.title('Total Cases vs GDP per Capita')
plt.xlabel('GDP per Capita')
plt.ylabel('Total Cases')
# Out:
# Text(0, 0.5, 'Total Cases')

# %%
#c. Plot Pairplot on df_groupby dataset.
pair_plot=sns.pairplot(df_groupby.sample(10))
print(pair_plot)

# %%
#d. Plot a bar plot of 'continent' column with 'total_cases' .Tip : using kind='bar' in seaborn catplot
sns.catplot('continent','total_cases', data=df, kind='bar')

# %%
#10.Save the df_groupby dataframe in your local drive using pandas.to_csv function .
df_groupby.to_csv('df_groupby.csv', index=False)
